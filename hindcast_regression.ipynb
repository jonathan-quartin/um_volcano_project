# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import os
from helper_functions import date_to_decimal_year, regressor, scatter_compare

# %%
folder_path = '/Users/jonathanquartin/Documents/Coding/GitHub/um_volcano_project/GALAPAGOS_DATA'

# %%
# Import tables
rainfall = pd.read_csv(os.path.join(folder_path, "cleaned_precip_galap.csv"))
eruptions = pd.read_csv(os.path.join(folder_path, "eruptions_galapagos3.csv"))

bellavista = pd.read_csv(os.path.join(folder_path, "climate_bellavista.csv"))
ayora = pd.read_csv(os.path.join(folder_path, "climate_puerto-ayora.csv"))

# %%
volcanos = {'Wolf': (-91.35, .05), 'Fernandina': (-91.55, -.35), 'Negra, Sierra': (-91.15, -.85), 'Azul, Cerro': (-91.35, -.95) } # Long/lat pairs must exist in rainfall data
pick = 'Negra, Sierra' # Choose a volcano to analyze rainfall at
compare_site = ayora  # Choose ayora or bellavista to compare rainfall to
site_name = 'Ayora' # Same choice as for compare_site, but as a string and capitalized
rolling_number = 90 # Number of days to average rainfall over
print_summary = True # Make true if you want to see summary of regression

# %%
regressor(rainfall, volcanos, pick, compare_site, rolling_number, print_summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               roll_two   R-squared:                       0.598
# Model:                            OLS   Adj. R-squared:                  0.598
# Method:                 Least Squares   F-statistic:                 1.226e+04
# Date:                Wed, 27 Dec 2023   Prob (F-statistic):               0.00
# Time:                        21:43:24   Log-Likelihood:                -9528.9
# No. Observations:                8254   AIC:                         1.906e+04
# Df Residuals:                    8252   BIC:                         1.908e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5129      0.009     54.466      0.000       0.494       0.531
# roll           0.8944      0.008    110.735      0.000       0.879       0.910
# ==============================================================================
# Omnibus:                     3140.121   Durbin-Watson:                   0.721
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            27954.538
# Skew:                           1.575   Prob(JB):                         0.00
# Kurtosis:                      11.447   Cond. No.                         1.65
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
scatter_compare(rainfall, volcanos, pick, compare_site, site_name, rolling_number)
